# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train=pd.read_csv("C:\\Users\\cheta\\Downloads\\train.csv")

# %%
train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train['Age'].fillna(train['Age'].median(),inplace=True)
train.drop(columns=['Cabin'],inplace=True)
train.dropna(subset=['Embarked'],inplace=True)
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
train['PassengerId'].value_counts().plot(kind='box')
plt.show()
train['Survived'].value_counts().plot(kind='box')
plt.show()
train['Pclass'].value_counts().plot(kind='box')
plt.show()
train['Name'].value_counts().plot(kind='box')
plt.show()
train['Sex'].value_counts().plot(kind='box')
plt.show()
train['Age'].value_counts().plot(kind='box')
plt.show()
train['SibSp'].value_counts().plot(kind='box')
plt.show()
train['Parch'].value_counts().plot(kind='box')
plt.show()
train['Ticket'].value_counts().plot(kind='box')
plt.show()
train['Fare'].value_counts().plot(kind='box')
plt.show()
train['Embarked'].value_counts().plot(kind='box')
plt.show()

# %%
test=pd.read_csv("C:\\Users\\cheta\\Downloads\\test.csv")

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test['Age'].fillna(test['Age'].median(),inplace=True)
test.dropna(subset=['Fare'],inplace=True)
test.drop(columns=['Cabin'],inplace=True)
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
test['PassengerId'].value_counts().plot(kind='box')
plt.show()
test['Pclass'].value_counts().plot(kind='box')
plt.show()
test['Name'].value_counts().plot(kind='box')
plt.show()
test['Sex'].value_counts().plot(kind='box')
plt.show()
test['Age'].value_counts().plot(kind='box')
plt.show()
test['SibSp'].value_counts().plot(kind='box')
plt.show()
test['Parch'].value_counts().plot(kind='box')
plt.show()
test['Ticket'].value_counts().plot(kind='box')
plt.show()
test['Fare'].value_counts().plot(kind='box')
plt.show()
test['Embarked'].value_counts().plot(kind='box')
plt.show()

# %%
Q1=test['Fare'].quantile(0.25)
Q3=test['Fare'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
test[(test['Fare'] >= lower_bound) & (test['Fare'] <= upper_bound)]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Embarked
# ...

# %%
test['PassengerId'].value_counts().plot(kind='box')
plt.show()
test['Pclass'].value_counts().plot(kind='box')
plt.show()
test['Name'].value_counts().plot(kind='box')
plt.show()
test['Sex'].value_counts().plot(kind='box')
plt.show()
test['Age'].value_counts().plot(kind='box')
plt.show()
test['SibSp'].value_counts().plot(kind='box')
plt.show()
test['Parch'].value_counts().plot(kind='box')
plt.show()
test['Ticket'].value_counts().plot(kind='box')
plt.show()
test['Fare'].value_counts().plot(kind='box')
plt.show()
test['Embarked'].value_counts().plot(kind='box')
plt.show()
